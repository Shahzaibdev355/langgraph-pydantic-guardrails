# %%
from pydantic import BaseModel

class Person(BaseModel):
    name: str
    age: int
    email: str

# %%
person = Person(name="shahzaib", age=15, email="test@gmail.com")
print(person)
# Out:
# name='shahzaib' age=15 email='test@gmail.com'

# %% [markdown]
# ### Model with optional field

# %%
from typing import Optional

class Employee(BaseModel):
    id: int
    name: str
    department: str
    salary: Optional[float] = None
    is_active: Optional[bool] = True

# %%
emp1 = Employee(id=1, name="john", department="IT")
print(emp1)
# Out:
# id=1 name='john' department='IT' salary=None is_active=True

# %% [markdown]
# ### List validation

# %%
from pydantic import BaseModel
from typing import List

class Classroom(BaseModel):
    room_number: str
    students: List[str]
    capacity: int


class1 = Classroom(
    room_number="22",  
    students= ["ali","john","sarah"],
    capacity=3
)

print(class1)
# Out:
# room_number='22' students=['ali', 'john', 'sarah'] capacity=3

# %%
try:
    invalid_val = Classroom(
    room_number="22",  
    students= ["ali", 123],
    capacity=3
    )

except ValueError as e:
    print(e)
# Out:
# 1 validation error for Classroom
# students.1
#   Input should be a valid string [type=string_type, input_value=123, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.13/v/string_type

# %% [markdown]
# ### Nested Models

# %%
from pydantic import BaseModel

class Address(BaseModel):
    street: str
    city: str
    zip_code: str


class Customer(BaseModel):
    customer_id: int
    name: str
    address: Address


customer = Customer(
    customer_id=1,
    name="Emma",
    address={
        "street": "123 main st",
        "city": "Boston",
        "zip_code": "2108"    
    }
)

print(customer)
# Out:
# customer_id=1 name='Emma' address=Address(street='123 main st', city='Boston', zip_code='2108')

# %% [markdown]
# ### Pydantic Fields: Customization and Constraints
#
# the field func in Pydantic enhance model field beyond basic type hints by allowing us to specify validation rules

# %%
from pydantic import BaseModel, Field

class Item(BaseModel):
    name: str = Field(min_length=8, max_length=10)
    # greater than 0 and less than 1000
    price: float = Field(gt=0, le=1000)
    quantity: int = Field(ge=0)


item = Item(name="Bookified", price=10, quantity=10)
print(item)
# Out:
# name='Bookified' price=10.0 quantity=10

# %%
from pydantic import BaseModel, Field

class User(BaseModel):
    username: str = Field(..., description="Unique username for the user")
    age: int = Field(default=18, description="User age, default to 18")
    email: str = Field(default_factory=lambda: "user@example.com", description="default email address")


user1 = User(username="alice")
print(user1)

user2 = User(username="bob", age=25, email="bob@domain.com")
print(user2)
# Out:
# username='alice' age=18 email='user@example.com'
# username='bob' age=25 email='bob@domain.com'
